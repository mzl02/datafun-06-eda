# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Load the dataset
file_path = '~/Documents/datafun-06-eda/gold_price_plus_metrics.csv'

df = pd.read_csv(file_path)

# %%
#Initial Data Inspection
print(df.head(10))
print(df.shape)
print(df.dtypes)
print(df.info())
# Out:
#       Date  Price 2 Days Prior  Price 1 Day Prior  Price Today  \
# 0   8/7/24             2405.87            2384.90      2385.83
# 1   8/6/24             2442.74            2405.87      2384.90
# 2   8/5/24             2447.17            2442.74      2405.87
# 3   8/2/24             2447.23            2447.17      2442.74
# 4   8/1/24             2411.09            2447.23      2447.17
# 5  7/31/24             2382.47            2411.09      2447.23
# 6  7/30/24             2387.11            2382.47      2411.09
# 7  7/29/24             2365.37            2387.11      2382.47
# 8  7/26/24             2400.12            2365.37      2387.11
# 9  7/25/24             2409.86            2400.12      2365.37
#
#    Price Tomorrow  Price Change Tomorrow  Price Change Ten  Std Dev 10  \
# 0             NaN                    NaN               NaN   30.155078
# 1         2385.83                   0.93               NaN   29.423936
# ...

# %%
#Initial Descriptive Statistics

print(df.describe())
# Out:
#        Price 2 Days Prior  Price 1 Day Prior  Price Today  Price Tomorrow  \
# count          676.000000         676.000000   676.000000      675.000000
# mean          1956.236228        1957.114305  1957.937944     1958.165600
# std            192.959980         193.560530   194.198338      194.252056
# min           1627.040000        1627.040000  1627.040000     1627.040000
# 25%           1823.587500        1824.490000  1824.490000     1824.880000
# 50%           1930.910000        1931.405000  1931.515000     1931.590000
# 75%           2021.452500        2022.290000  2023.977500     2024.075000
# max           2469.650000        2469.650000  2469.650000     2469.650000
#
#        Price Change Tomorrow  Price Change Ten  Std Dev 10  \
# count             675.000000        666.000000  667.000000
# mean                0.861570          8.944414   20.995813
# std                17.531773         55.681937   10.470747
# min               -81.890000       -124.290000    5.587177
# ...

# %%
#Initial Data Distribution for Numerical Columns

# Inspect histogram by numerical column
df["Price Today"].hist()

# Inspect histograms for all numerical columns
df.hist()

# Show all plots
plt.show()

# %%
#Initial Data Distribution for Categorical Columns

# Check for categorical columns
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
print("Categorical columns:", categorical_columns)

# Loop through all categorical columns and plot their distributions
for col in categorical_columns:
    print(f"Value counts for {col}:\n", df[col].value_counts())
    
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.show()

# Show all plots
plt.show()
# Out:
# Categorical columns: Index(['Date'], dtype='object')
# Value counts for Date:
#  Date
# 8/7/24      1
# 11/8/22     1
# 11/18/22    1
# 11/17/22    1
# 11/16/22    1
#            ..
# 9/22/23     1
# 9/21/23     1
# 9/20/23     1
# 9/19/23     1
# 1/3/22      1
# Name: count, Length: 676, dtype: int64

# %%
#Initial Data Preparation (or Data Preprocessing)

#Price 2 Days Prior     old
#Price_2_Days_Prior     new

df.rename(columns={'Price 2 Days Prior': 'Price_2_Days_Priors'}, inplace=True)



#Price 1 Day Prior      old
#Price_1_Day_Prior      new

df.rename(columns={'Price 1 Day Prior': 'Price_1_Days_Priors'}, inplace=True)


#Price Today            old
#Price_Today            new

df.rename(columns={'Price Today': 'Price_Today'}, inplace=True)


#Price Tomorrow         old
#Price_Tomorrow         new

df.rename(columns={'Price Tomorrow': 'Price_Tomorrow'}, inplace=True)



#Price Change Tomorrow   old
#Price_Change_Tomorrow   new

df.rename(columns={'Price Change Tomorrow': 'Price_Change_Tomorrow'}, inplace=True)

#Price Change Ten       old
#Price_Change_Ten       new

df.rename(columns={'Price Change Ten': 'Price_Change_Ten'}, inplace=True)

#Std Dev 10             old
#Std_Dev_10             new

df.rename(columns={'Std Dev 10': 'Std_Dev_10'}, inplace=True)


#Twenty Moving Average  old
#Twenty_Moving_Average  new

df.rename(columns={'Twenty Moving Average': 'Twenty_Moving_Average'}, inplace=True)



#Fifty Day Moving Average   old
#Fifty_Day_Moving_Average   new

df.rename(columns={'Fifty Day Moving Average': 'Fifty_Day_Moving_Average'}, inplace=True)



#200 Day Moving Average     old
#200_Day_Moving_Average     new

df.rename(columns={'200 Day Moving Average': '200_Day_Moving_Average'}, inplace=True)


#Monthly Inflation Rate     old
#Monthly_Inflation_Rate     new

df.rename(columns={'Monthly Inflation Rate': 'Monthly_Inflation_Rate'}, inplace=True)

#EFFR Rate                  old
#EFFR_Rate                  new

df.rename(columns={'EFFR Rate': 'EFFR_Rate'}, inplace=True)

#Volume  No change

#Treasury Par Yield Month   old
#Treasury_Par_Yield_Month   new 

df.rename(columns={'Treasury Par Yield Month': 'Treasury_Par_Yield_Month'}, inplace=True)


#Treasury Par Yield Curve Rates (10 Yr)     old
#Treasury_Par_Yield_Curve_Rates_(10 Yr)     new

df.rename(columns={'Treasury Par Yield Curve Rates (10 Yr)': 'Treasury_Par_Yield_Curve_Rates_(10 Yr)'}, inplace=True)

#DXY            No Change

#SP Open        old
#SP_Open        new

df.rename(columns={'SP Open': 'SP_Open'}, inplace=True)

#VIX            No Change
#Crude          No Change



#Date,Price 2 Days Prior,Price 1 Day Prior,Price Today,Price Tomorrow,Price Change Tomorrow,Price Change Ten,Std Dev 10,Twenty Moving Average,Fifty Day Moving Average,200 Day Moving Average,Monthly Inflation Rate,EFFR Rate,Volume ,Treasury Par Yield Month,Treasury Par Yield Two Year,Treasury Par Yield Curve Rates (10 Yr),DXY,SP Open,VIX,Crude

# %%
#Check Output Again

print(df.describe())
# Out:
#        Price_2_Days_Priors  Price_1_Days_Priors  Price_Today  Price_Tomorrow  \
# count           676.000000           676.000000   676.000000      675.000000
# mean           1956.236228          1957.114305  1957.937944     1958.165600
# std             192.959980           193.560530   194.198338      194.252056
# min            1627.040000          1627.040000  1627.040000     1627.040000
# 25%            1823.587500          1824.490000  1824.490000     1824.880000
# 50%            1930.910000          1931.405000  1931.515000     1931.590000
# 75%            2021.452500          2022.290000  2023.977500     2024.075000
# max            2469.650000          2469.650000  2469.650000     2469.650000
#
#        Price_Change_Tomorrow  Price_Change_Ten  Std_Dev_10  \
# count             675.000000        666.000000  667.000000
# mean                0.861570          8.944414   20.995813
# std                17.531773         55.681937   10.470747
# ...

# %%
### Time Series Plot: Price Today Over Time ###
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Price_Today'], label='Price Today')
plt.title('Price Today Over Time')
plt.xlabel('Date')
plt.ylabel('Price Today')
plt.xticks(rotation=45)
plt.show()

# %%
### Time Series: Price Today with Moving Averages ###
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Price_Today'], label='Price Today')
plt.plot(df['Date'], df['Twenty_Moving_Average'], label='20-Day MA')
plt.plot(df['Date'], df['Fifty_Day_Moving_Average'], label='50-Day MA')
plt.plot(df['Date'], df['200_Day_Moving_Average'], label='200-Day MA')
plt.title('Price Today with Moving Averages Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
### Histogram: Price Change Tomorrow ###
plt.figure(figsize=(8, 6))
sns.histplot(df['Price_Change_Tomorrow'], bins=50, kde=True)
plt.title('Distribution of Price Change Tomorrow')
plt.xlabel('Price Change Tomorrow')
plt.ylabel('Frequency')
plt.show()

# %%
### Histogram: Std Dev 10 ###
plt.figure(figsize=(8, 6))
sns.histplot(df['Std_Dev_10'], bins=50, kde=True)
plt.title('Distribution of 10-Day Standard Deviation')
plt.xlabel('Standard Deviation')
plt.ylabel('Frequency')
plt.show()

# %%
### Scatter Plot: DXY vs Price Today ###
plt.figure(figsize=(8, 6))
sns.scatterplot(x='DXY', y='Price_Today', data=df)
plt.title('DXY vs Price Today')
plt.xlabel('DXY (Dollar Index)')
plt.ylabel('Price Today')
plt.show()

# %%
### Scatter Plot: VIX vs Std Dev 10 ###
plt.figure(figsize=(8, 6))
sns.scatterplot(x='VIX', y='Std_Dev_10', data=df)
plt.title('VIX vs 10-Day Standard Deviation')
plt.xlabel('VIX')
plt.ylabel('10-Day Standard Deviation')
plt.show()

# %%
### Scatter Plot: 10-Year Treasury Yield vs Price Today ###
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Treasury_Par_Yield_Curve_Rates_(10 Yr)', y='Price_Today', data=df)
plt.title('10-Year Treasury Yield vs Price Today')
plt.xlabel('10-Year Treasury Yield')
plt.ylabel('Price Today')
plt.show()

# %%
### Scatter Plot: Inflation Rate vs Price Today ###
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Monthly_Inflation_Rate', y='Price_Today', data=df)
plt.title('Inflation Rate vs Price Today')
plt.xlabel('Inflation Rate')
plt.ylabel('Price Today')
plt.show()
